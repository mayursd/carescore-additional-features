# %%
## Read and modify doc file

from docx import Document

doc = Document('D:\LOF\careScoreAI\carescore-main\carescore-main\SOAP_Note Template.docx')

# %%
doc.tables[0].row_cells(0)[0].text
# Out:
# 'HPI: (onset, location, duration, character, aggravating/ alleviating, radiation, timing, severity):\n'

# %%
doc.tables[1].row_cells(0)[0].text
doc.tables[1].row_cells(0)[1].text
# Out:
# 'FHx: (parents, siblings, children, dx and ages):\n'

# %%
doc.tables[2].row_cells(0)[0].text
doc.tables[2].row_cells(0)[1].text
doc.tables[2].row_cells(1)[1].text
# Out:
# 'Allergies: (specify type of reaction)'

# %%
doc.tables[3].row_cells(0)[0].text
# Out:
# 'Review of Systems:  Include pertinent + and negatives and elaborate where needed.  Remove what was not asked\n\nGeneral: \n\nEyes: \n\n Ears, Nose, and Throat (ENT): \n\nCardiovascular: \n\nRespiratory: \n\nGastrointestinal: \n\nGenitourinary: \n\nMusculoskeletal: \n\nNeurological: \n\nPsychiatric: \n\nIntegument/Skin: \n\nEndocrine: \n\nHematopoietic/Lymphatic: \n\nAllergy/Immunology: '

# %%
doc.tables[6].row_cells(0)[0].text
doc.tables[8].row_cells(0)[0].text
# Out:
# '\nFinal diagnosis or problems(s)\nInvestigations (labs, imaging, etc)\nMedications:\xa0 (specific medication, dose, route, frequency)\nConsults:\nDisposition (Admit, d/c, observe, follow up with, when?)\nPt Education:\nOther:\n\n'

# %%
print(doc.tables[0].row_cells(0)[0].text)
print("___________________________ ")
print(doc.tables[1].row_cells(0)[0].text)
print("___________________________ ")
print(doc.tables[1].row_cells(0)[1].text)
print("___________________________ ")
print(doc.tables[2].row_cells(0)[0].text)
print("___________________________ ")
print(doc.tables[2].row_cells(0)[1].text)
print("___________________________ ")
print(doc.tables[2].row_cells(1)[1].text)
print("___________________________ ")
print(doc.tables[3].row_cells(0)[0].text)
print("___________________________ ")
print(doc.tables[6].row_cells(0)[0].text)
print("___________________________ ")
print(doc.tables[8].row_cells(0)[0].text)
print("___________________________ ")
# Out:
# HPI: (onset, location, duration, character, aggravating/ alleviating, radiation, timing, severity):
#
# ___________________________
# PMHx: (childhood/ adult illnesses, immunizations, hospitalizations, surgical history):
# ___________________________
# FHx: (parents, siblings, children, dx and ages):
#
# ___________________________
# SHx:
# Tobacco:  type, number of pack years
# ETOH:  type, amount,  frequency,
# Drugs: type, amount, frequency
# Diet:
# Exercise:
# Sexual activity:
# Occupation:
# Living situation:
# Safety:
# ___________________________
# Medications: (dose, frequency, route, etc, include OTC)
#
#
#
#
# ___________________________
# Allergies: (specify type of reaction)
# ___________________________
# Review of Systems:  Include pertinent + and negatives and elaborate where needed.  Remove what was not asked
#
# General:
#
# Eyes:
#
#  Ears, Nose, and Throat (ENT):
#
# Cardiovascular:
#
# Respiratory:
#
# Gastrointestinal:
#
# Genitourinary:
#
# Musculoskeletal:
#
# ...
